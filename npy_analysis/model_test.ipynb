# %% [markdown]
# # Model Cross Testing Notebook

# %% [markdown]
# Use this notebook to test a model on different test data. It's more compact than the model_test.ipynb notebook

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os
from seismic_purifier.config import BATCH_SIZE
from seismic_purifier.representation_learning_models import (
    RepresentationLearningSingleAutoencoder,
    RepresentationLearningDenoisingSingleAutoencoder,
    RepresentationLearningMultipleAutoencoder
)
from seismic_purifier.classifier_models import (
    ClassifierAutocovariance, 
    ClassifierAugmentedAutoencoder, 
    ClassifierMultipleAutoencoder
)
import matplotlib.pyplot as plt
# Out:
# 2025-06-29 13:37:21.835371: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-29 13:37:21.901640: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-29 13:37:21.901682: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-29 13:37:21.901771: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-29 13:37:21.914877: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-29 13:37:21.917194: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-29 13:37:23.359509: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_curve, roc_auc_score

# %%
tf.keras.backend.clear_session()
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        # Limit memory growth to avoid consuming all GPU memory
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
    except RuntimeError as e:
        print(e)

# %%
# ============================
# 1. Configuration
# ============================
TEST_STATION_NAME="GAZK"
MODEL_STATION_NAME="MRMT"

TEST_DATA_PATH = f'/home/ege/rawcovar_data/2020-09-07_WEEK/processed_data/{TEST_STATION_NAME}.npy' 
TEST_LABEL_PATH = f"/home/ege/rawcovar_data/2020-09-07_WEEK/processed_data/{TEST_STATION_NAME}_y_condensed.npy"

MODEL_PATH = f'/home/ege/rawcovar/experiments/JUNE2025/28JUNE2025/1WEEK_CONTINUOUS_EXP_3_2020-09/models/{MODEL_STATION_NAME}_representation_multiple_5epochs.h5'

# %%
# ============================
# 2. Data loading
# ============================
X_test = np.load(TEST_DATA_PATH)
print(f"Test data shape: {X_test.shape}")

Y_test = np.load(TEST_LABEL_PATH)  # Expected shape: (num_samples)
print(f"Test label shape: {Y_test.shape}")
# Out:
# Test data shape: (19968, 3000, 3)
# Test label shape: (19968,)

# %%
# ============================
# 3. Representation Learning Model Instantiation
# ============================

# Choose the model you want to train
# For example, using RepresentationLearningSingleAutoencoder
#model = RepresentationLearningSingleAutoencoder(
 #name="rep_learning_autoencoder"
#)

# Alternatively, you can choose other models:
#model = RepresentationLearningDenoisingSingleAutoencoder(
 #    name="rep_learning_denoising_autoencoder",
  #   input_noise_std=1e-6,
   #  denoising_noise_std=2e-1
 #)
model = RepresentationLearningMultipleAutoencoder(
     name="rep_learning_autoencoder_ensemble",
     input_noise_std=1e-6,
     eps=1e-27
)

# %%
# ============================
# 4. Model Compilation
# ============================
model.compile()
model(X_test)
# Out:
# (<tf.Tensor: shape=(19968, 94, 64), dtype=float32, numpy=
#  array([[[ 6.96531963e-03,  2.90599596e-02, -1.42868340e-01, ...,
#           -2.99171716e-01, -4.65223975e-02, -4.58053611e-02],
#          [ 1.40116829e-02, -4.86511588e-02, -2.76309196e-02, ...,
#           -3.27822953e-01, -4.14524227e-02, -1.01200193e-01],
#          [-1.50293065e-02,  1.80399179e-01, -5.21855243e-02, ...,
#           -2.90363759e-01, -6.34960458e-02, -3.77342640e-03],
#          ...,
#         [[ 2.48302266e-01,  6.96586212e-03, -1.09234788e-01, ...,
#           -2.03739464e-01, -7.29786381e-02,  1.51448980e-01],
#          [ 1.61325276e-01,  9.40405950e-03, -1.71302333e-01, ...,
#           -8.92415419e-02, -2.24451348e-01,  2.08610713e-01],
#          [ 2.83383876e-01,  2.32294034e-02, -1.29118964e-01, ...,
#           -2.11020157e-01, -1.23632468e-01,  1.27076834e-01],
#          ...,
#          [ 3.67947727e-01,  2.87806918e-03, -9.72211435e-02, ...,
#           -2.90401191e-01, -1.13740407e-01,  2.74273962e-01],
#          [ 4.67444539e-01,  6.81292340e-02, -3.56192619e-01, ...,
#           -2.82457322e-01, -1.58080846e-01,  2.31708169e-01],
#          [ 3.92195612e-01, -1.57091934e-02, -1.51478693e-01, ...,
#           -2.78061032e-01, -2.01632857e-01,  2.71482140e-01]]],
#        dtype=float32)>,
#  <tf.Tensor: shape=(19968, 94, 64), dtype=float32, numpy=
#  array([[[ 0.04212119,  0.54761016, -0.1603148 , ...,  0.3258229 ,
#           -0.49773136, -0.39598224],
#          [-0.01040804,  0.6495836 , -0.08664922, ...,  0.2186798 ,
#           -0.57083255, -0.54939467],
#          [ 0.09380671,  0.5499134 , -0.09823374, ...,  0.1431205 ,
#           -0.5661263 , -0.4960922 ],
#          ...,
#          [ 0.06007673,  0.4421276 , -0.00477412, ...,  0.04629408,
#           -0.3141771 , -0.42157364],
#          [ 0.04939585,  0.3338727 , -0.02933973, ...,  0.05366118,
#           -0.29793656, -0.29268828],
#          [ 0.08615629,  0.33827195, -0.07467838, ...,  0.13401322,
#           -0.2707974 , -0.23055843]],
#
#         [[ 0.02753643,  0.59838456, -0.13983825, ...,  0.13860787,
#           -0.45577842, -0.35790882],
#          [ 0.10372725,  0.63890016, -0.16778103, ...,  0.13567205,
#           -0.39531282, -0.4566532 ],
#          [ 0.08628115,  0.64670724, -0.07829307, ...,  0.1844901 ,
#           -0.57377225, -0.4737907 ],
#          ...,
#          [ 0.02055684,  0.64976937, -0.05856931, ...,  0.14434719,
#           -0.66546154, -0.5657212 ],
#          [ 0.05192984,  0.42932594, -0.11119285, ...,  0.19987445,
#           -0.5472869 , -0.36770967],
#          [ 0.05120678,  0.5456016 , -0.18863146, ...,  0.10064788,
#           -0.47618276, -0.43718293]],
#
#         [[ 0.03329532,  0.5121177 , -0.13037105, ...,  0.10854699,
#           -0.34435838, -0.38668892],
#          [ 0.09229966,  0.4089115 , -0.11824095, ...,  0.15589368,
#           -0.36344892, -0.35991225],
#          [ 0.14927678,  0.548058  , -0.08513001, ...,  0.1153332 ,
#           -0.40056697, -0.41449484],
#          ...,
#          [ 0.05315394,  0.275437  , -0.04081097, ...,  0.0931032 ,
#           -0.20647447, -0.24867295],
#          [ 0.01712616,  0.2697055 , -0.0636134 , ...,  0.09880828,
#           -0.2341267 , -0.21858323],
#          [ 0.08402494,  0.19822848, -0.03137191, ...,  0.09557188,
#           -0.2182808 , -0.1879993 ]],
#
#         ...,
#
#         [[ 0.00959283,  0.42430174, -0.031928  , ...,  0.13055351,
#           -0.32395533, -0.33579695],
#          [ 0.02382007,  0.4512974 , -0.03870675, ...,  0.19582205,
#           -0.2898243 , -0.3544771 ],
#          [ 0.08096559,  0.3847315 , -0.09097336, ...,  0.08813943,
#           -0.28536478, -0.35629457],
#          ...,
#          [ 0.07926144,  0.7727547 , -0.17144524, ...,  0.26230884,
#           -0.4432676 , -0.4852527 ],
#          [ 0.07323075,  0.6573143 , -0.08978532, ...,  0.22478175,
#           -0.45807058, -0.5142226 ],
#          [ 0.20381221,  0.69977444, -0.0569201 , ...,  0.3106993 ,
#           -0.41026637, -0.5802077 ]],
#
#         [[ 0.06506045,  0.5579437 , -0.02059151, ...,  0.11122709,
#           -0.46154484, -0.43060926],
#          [ 0.03973408,  0.544152  , -0.092838  , ...,  0.19219415,
#           -0.41306725, -0.38894156],
#          [ 0.06473155,  0.5618905 , -0.06311096, ...,  0.17040028,
#           -0.35768664, -0.41139153],
#          ...,
#          [ 0.05675354,  0.4979408 , -0.03417711, ...,  0.19597657,
#           -0.3329809 , -0.3618445 ],
#          [-0.00177046,  0.5519658 , -0.07162365, ...,  0.10527076,
#           -0.32006317, -0.35610515],
#          [-0.01076613,  0.45543206, -0.08985764, ...,  0.26122   ,
#           -0.32744378, -0.33565694]],
#
#         [[ 0.11366878,  0.40146616, -0.16308792, ...,  0.09557699,
#           -0.27596882, -0.3080778 ],
#          [ 0.07105781,  0.43007758, -0.16318733, ...,  0.1424051 ,
#           -0.3023309 , -0.26663327],
#          [ 0.02368337,  0.40977806, -0.14865749, ...,  0.13231349,
#           -0.33747515, -0.3396832 ],
#          ...,
#          [ 0.11974713,  0.46778563, -0.11961179, ...,  0.15600428,
#           -0.33753413, -0.32376233],
#          [ 0.13372037,  0.48503688, -0.0843458 , ...,  0.10670064,
#           -0.23847288, -0.36256707],
#          [ 0.09193044,  0.42854947, -0.04366982, ...,  0.20893288,
#           -0.34738564, -0.42259476]]], dtype=float32)>,
#  <tf.Tensor: shape=(19968, 94, 64), dtype=float32, numpy=
#  array([[[ 5.51346064e-01,  4.81468022e-01, -6.57417998e-02, ...,
#           -6.77743182e-02, -5.83495665e-03,  1.25126183e-01],
#          [ 5.47831655e-01,  4.95197535e-01, -1.14284344e-02, ...,
#           -1.11821026e-01,  2.08359044e-02,  1.29906535e-01],
#          [ 5.17799258e-01,  4.90721494e-01, -4.22898419e-02, ...,
#           -1.89231560e-01,  3.36608067e-02,  5.99160232e-02],
#          ...,
#          [ 4.14339066e-01,  5.39401412e-01,  5.56920618e-02, ...,
#           -1.62484616e-01,  1.63059141e-02,  5.13480529e-02],
#          [ 5.15764892e-01,  4.89023864e-01, -6.46834373e-02, ...,
#           -2.23196283e-01, -1.60722464e-01, -4.98138592e-02],
#          [ 3.78976732e-01,  4.20623451e-01,  3.96066643e-02, ...,
#           -1.30037025e-01, -1.98060041e-03,  5.05668037e-02]],
#
#         [[ 5.55416822e-01,  6.84352756e-01,  1.26116335e-01, ...,
#           -2.26483271e-01, -1.27247587e-01, -6.16197474e-02],
#          [ 5.06573975e-01,  7.43173838e-01,  6.30606012e-03, ...,
#           -1.53513610e-01, -5.84492385e-02,  3.38740200e-02],
#          [ 3.95156145e-01,  5.08313835e-01, -3.13613899e-02, ...,
#           -7.94142634e-02, -7.92133994e-03,  5.92111470e-03]],
#
#         [[ 3.53695005e-01,  5.94117701e-01,  1.54602882e-02, ...,
#           -2.44548827e-01, -5.92593066e-02, -1.24102132e-02],
#          [ 4.35402483e-01,  4.33089703e-01,  8.02233443e-02, ...,
#           -1.08884715e-01, -4.35991725e-03,  4.34104875e-02],
#          [ 4.03805375e-01,  4.62734550e-01, -7.46605098e-02, ...,
#           -1.28649831e-01, -1.15916124e-02,  3.90890799e-02],
#          ...,
#          [ 5.10845661e-01,  7.00953960e-01,  8.56380984e-02, ...,
#           -2.62188286e-01, -6.09625541e-02,  8.26874152e-02],
#          [ 3.82019877e-01,  6.25369668e-01,  1.63958758e-01, ...,
#           -2.69509524e-01, -4.60246317e-02, -1.06135465e-01],
#          [ 6.14861965e-01,  4.81022835e-01, -1.84462871e-02, ...,
#           -2.85230696e-01, -1.38530225e-01,  4.27635536e-02]]],
#        dtype=float32)>,
#  <tf.Tensor: shape=(19968, 94, 64), dtype=float32, numpy=
#  array([[[ 0.49457505,  0.5153415 , -0.03981982, ...,  0.11069159,
#           -0.49137703,  0.54446375],
#          [ 0.42841643,  0.48354173, -0.13302408, ...,  0.04154835,
#           -0.56122684,  0.739282  ],
#          [ 0.5662601 ,  0.48733526, -0.08275785, ...,  0.05794657,
#           -0.57526773,  0.61548585],
#          ...,
#          [ 0.5187896 ,  0.3239307 , -0.15190364, ...,  0.08475363,
#           -0.47867212,  0.6065342 ],
#          [ 0.51956826,  0.45732215, -0.02441158, ...,  0.07678187,
#           -0.5152084 ,  0.6300328 ],
#          [ 0.46832293,  0.40053236, -0.12004504, ...,  0.02183177,
#           -0.42395726,  0.592847  ]],
#
#         [[ 0.5500447 ,  0.3901375 , -0.05098795, ...,  0.0718394 ,
#           -0.54037184,  0.73019415],
#          [ 0.4128993 ,  0.42249656, -0.09680825, ...,  0.08303931,
#           -0.6006926 ,  0.68688345],
#          [ 0.48671088,  0.6109266 , -0.03226209, ...,  0.1315563 ,
#           -0.4729799 ,  0.8169132 ],
#          ...,
#          [ 0.5217166 ,  0.62224764,  0.02526241, ...,  0.23232536,
#           -0.49279633,  0.85955787],
#          [ 0.65239394,  0.63526434, -0.1425077 , ...,  0.02480897,
#           -0.5246166 ,  0.82325625],
#          [ 0.48121816,  0.6235251 ,  0.01552455, ...,  0.11558721,
#           -0.5955808 ,  0.81270283]],
#
#         [[ 0.3362444 ,  0.36877394, -0.06102226, ...,  0.07541969,
#           -0.35188863,  0.5094207 ],
#          [ 0.38743204,  0.41893402, -0.04628681, ...,  0.11317852,
#           -0.42677355,  0.3626646 ],
#          [ 0.39175272,  0.44673628, -0.08752757, ..., -0.0294319 ,
#           -0.32623824,  0.54736996],
#          ...,
#          [ 0.46667883,  0.3753696 , -0.01078398, ...,  0.04155297,
#           -0.42264852,  0.686536  ],
#          [ 0.25847173,  0.4973669 , -0.09897528, ...,  0.08197687,
#           -0.38474226,  0.6379465 ],
#          [ 0.39687315,  0.4514627 , -0.08254378, ...,  0.04158493,
#           -0.5110427 ,  0.6227774 ]],
#
#         ...,
#
#         [[ 0.65963835,  0.48481563, -0.19968627, ...,  0.03351856,
#           -0.6108078 ,  0.8583268 ],
#          [ 0.5403725 ,  0.53463715, -0.08963648, ..., -0.09810473,
#           -0.52109784,  0.9106556 ],
#          [ 0.5797667 ,  0.53263134, -0.11601844, ...,  0.03049766,
#           -0.68737894,  0.70302194],
#          ...,
#          [ 0.5599978 ,  0.67064625, -0.00575267, ...,  0.07946656,
#           -0.5763049 ,  0.6843555 ],
#          [ 0.5252681 ,  0.68647194, -0.05779696, ...,  0.1622807 ,
#           -0.5543268 ,  0.75185215],
#          [ 0.4832201 ,  0.68003565,  0.11253089, ..., -0.00907533,
#           -0.5465153 ,  0.7944678 ]],
#
#         [[ 0.45114014,  0.5498704 , -0.10060324, ..., -0.01712814,
#           -0.45805228,  0.7989721 ],
#          [ 0.5003025 ,  0.5589697 , -0.12527159, ...,  0.11643396,
#           -0.33728546,  0.65649366],
#          [ 0.4943903 ,  0.5962257 , -0.0773679 , ...,  0.14665408,
#           -0.54765564,  0.6484186 ],
#          ...,
#          [ 0.45709398,  0.45420825,  0.05323532, ...,  0.01909743,
#           -0.5311876 ,  0.6710187 ],
#          [ 0.5379142 ,  0.55540425, -0.19597372, ...,  0.2324061 ,
#           -0.4526478 ,  0.6190673 ],
#          [ 0.717313  ,  0.48814735, -0.01807384, ..., -0.02891655,
#           -0.5234884 ,  0.8728089 ]],
#
#         [[ 0.5519859 ,  0.5055298 , -0.03384838, ...,  0.02296538,
#           -0.46434322,  0.6741664 ],
#          [ 0.4971326 ,  0.52880245, -0.10283365, ...,  0.09948287,
#           -0.40403736,  0.685398  ],
#          [ 0.52084637,  0.5947446 , -0.01596453, ..., -0.09593974,
#           -0.65247387,  0.78497636],
#          ...,
#          [ 0.47690517,  0.48742083,  0.03452644, ...,  0.17156114,
#           -0.68489903,  0.8423419 ],
#          [ 0.65183127,  0.61557513, -0.0890831 , ...,  0.00656549,
#           -0.60382444,  0.81266725],
#          [ 0.61013883,  0.39314055, -0.00834851, ...,  0.10592123,
#           -0.73066527,  0.8662542 ]]], dtype=float32)>,
#  <tf.Tensor: shape=(19968, 3000, 3), dtype=float32, numpy=
#  array([[[-0.2775253 ,  0.04681516,  0.20969684],
#          [-0.265966  ,  0.0481534 ,  0.20770963],
#          [-0.2601034 ,  0.05308705,  0.20793235],
#          ...,
#          [-0.10240795,  0.02290861,  0.07696369],
#          [-0.10683148,  0.02420797,  0.07947258],
#          [-0.10570572,  0.02376258,  0.07544199]],
#
#         [[-0.25245366,  0.04862908,  0.16542637],
#          [-0.25990766,  0.04993503,  0.174221  ],
#          [-0.26249322,  0.05299505,  0.17060024],
#          ...,
#          [-0.23336066,  0.05096791,  0.1449576 ],
#          [-0.23197486,  0.05452959,  0.13710205],
#          [-0.22381037,  0.05992731,  0.13589863]],
#
#         [[-0.20994057,  0.03777624,  0.14290276],
]],
#        dtype=float32)>,
#  <tf.Tensor: shape=(19968, 3000, 3), dtype=float32, numpy=
#  array([[[-0.15778697,  0.09399746,  0.11981782],
#          [-0.1643492 ,  0.09050369,  0.12047381],
#          [-0.1584157 ,  0.09935224,  0.12107793],
#          ...,
#          [-0.06002946, -0.00484935,  0.06694313],
#          [-0.05942068, -0.00231019,  0.06544002],
#          [-0.05268195, -0.00384503,  0.06322931]],
#
#         [[-0.0870827 , -0.00133291,  0.09823097],
#          [-0.09329491,  0.00198209,  0.09761482],
#          [-0.09490349,  0.00113527,  0.09187746],
#          ...,
#          [-0.10668547,  0.03472557,  0.11210617],
#          [-0.1059886 ,  0.03086093,  0.10813007],
#          [-0.08715279,  0.03203182,  0.10543436]],
#
#         [[-0.0436982 , -0.0161215 ,  0.0494927 ],
#          [-0.04547527, -0.01370239,  0.04891543],
#          [-0.04560382, -0.01605329,  0.04428412],
#          ...,
#          [-0.06962384,  0.03493362,  0.0582897 ],
#          [-0.07171407,  0.03708262,  0.06062577],
#          [-0.08174269,  0.03549206,  0.06094865]],
#
#         ...,
#
#         [[-0.05170604, -0.00639032,  0.04444214],
#          [-0.05224541, -0.00737026,  0.04252613],
#          [-0.052996  , -0.00537839,  0.04286692],
#          ...,
#          [-0.05860605, -0.02891575,  0.06281766],
#          [-0.06877037, -0.03524395,  0.05955875],
#          [-0.05657981, -0.03113298,  0.0603887 ]],
#
#         [[-0.10954771,  0.05352068,  0.09458148],
#          [-0.110999  ,  0.05960939,  0.09452531],
#          [-0.1128649 ,  0.05831108,  0.09484993],
#          ...,
#          [-0.03211261, -0.01160152,  0.02318399],
#          [-0.03066245, -0.01439279,  0.02509516],
#          [-0.0305172 , -0.01459499,  0.02378789]],
#
#         [[-0.06649863,  0.02124153,  0.06875572],
#          [-0.07175143,  0.02536127,  0.06793475],
#          [-0.07473987,  0.0217352 ,  0.05906441],
#          ...,
#          [-0.04231916, -0.0110723 ,  0.03828027],
#          [-0.04414176, -0.01496434,  0.0394034 ],
#          [-0.04114649, -0.01086095,  0.0451939 ]]], dtype=float32)>,
#  <tf.Tensor: shape=(19968, 3000, 3), dtype=float32, numpy=
#  array([[[-0.08048213,  0.20678401, -0.26495767],
#          [-0.07853949,  0.20462796, -0.26565328],
#          [-0.07923491,  0.20732923, -0.26764554],
#          ...,
#          [-0.08707429,  0.21839586, -0.28534362],
#          [-0.08753095,  0.21859813, -0.28728288],
#          [-0.08976366,  0.21853043, -0.28864315]],
#
#         [[-0.12338065,  0.28865   , -0.40990445],
#          [-0.13485928,  0.29418898, -0.40975028],
#          [-0.1263712 ,  0.3020465 , -0.4031225 ],
#          ...,
#          [-0.05332789,  0.1194    , -0.16376495],
#          [-0.0590727 ,  0.12023903, -0.16793492],
#          [-0.05211237,  0.12333597, -0.16433403]],
#
#         [[-0.08793717,  0.20567068, -0.2943396 ],
#          [-0.09349204,  0.20482235, -0.2976528 ],
#          [-0.09167032,  0.20251957, -0.28907624],
#          ...,
#          [-0.04317855,  0.12658721, -0.14979531],
#          [-0.04178039,  0.12589599, -0.14666411],
#          [-0.04312559,  0.12302293, -0.14492881]],
#
#         ...,
#
#         [[-0.06925862,  0.2106011 , -0.24080727],
#          [-0.07178713,  0.2148777 , -0.2399389 ],
#          [-0.07267373,  0.21541633, -0.24194075],
#          ...,
#          [-0.0900756 ,  0.23126608, -0.26541942],
#          [-0.08748277,  0.2280642 , -0.26265594],
#          [-0.08485277,  0.22312571, -0.268671  ]],
#
#         [[-0.13055639,  0.316702  , -0.4495244 ],
#          [-0.13631257,  0.32488024, -0.45047238],
#          [-0.12542087,  0.33206734, -0.4570176 ],
#          ...,
#          [-0.09395597,  0.24173298, -0.3109795 ],
#          [-0.09580436,  0.24072091, -0.31236866],
#          [-0.09698304,  0.242636  , -0.31635907]],
#
#         [[-0.06165302,  0.14160188, -0.2013482 ],
#          [-0.06233411,  0.1431464 , -0.20072564],
#          [-0.06044013,  0.14904794, -0.20373793],
#          ...,
#          [-0.143602  ,  0.36066854, -0.47408962],
#          [-0.14094198,  0.35393336, -0.46605733],
#          [-0.13902447,  0.3601331 , -0.47929275]]], dtype=float32)>,
#  <tf.Tensor: shape=(19968, 3000, 3), dtype=float32, numpy=
#  array([[[ 0.24201462, -0.48721755,  0.63558084],
#          [ 0.23423201, -0.5020878 ,  0.62834764],
#          [ 0.23435864, -0.5108912 ,  0.6369537 ],
#          ...,
#          [ 0.17278925, -0.3948969 ,  0.48892948],
#          [ 0.17346272, -0.38750908,  0.48752567],
#          [ 0.17217496, -0.3876825 ,  0.48612198]],
#
#         [[ 0.16880661, -0.38978475,  0.49942806],
#          [ 0.181168  , -0.37258473,  0.51380163],
#          [ 0.19069888, -0.35891816,  0.5008819 ],
#          ...,
#          [ 0.2688877 , -0.54258734,  0.726625  ],
#          [ 0.26521197, -0.5484224 ,  0.7245639 ],
#          [ 0.26319048, -0.5489663 ,  0.7183036 ]],
#
#         [[ 0.11529898, -0.26649016,  0.3411477 ],
#          [ 0.12060542, -0.25279248,  0.3426426 ],
#          [ 0.12830865, -0.24683264,  0.34295127],
#          ...,
#          [ 0.19940333, -0.45159024,  0.5666022 ],
#          [ 0.20854019, -0.44810605,  0.5632122 ],
#          [ 0.20663126, -0.4552297 ,  0.5709578 ]],
#
#         ...,
#
#         [[ 0.28303224, -0.582551  ,  0.74861664],
#          [ 0.27430552, -0.5913566 ,  0.7375174 ],
#          [ 0.26439556, -0.59226686,  0.7427025 ],
#          ...,
#          [ 0.269014  , -0.54455477,  0.70976174],
#          [ 0.26049984, -0.55242616,  0.70880693],
#          [ 0.26069427, -0.5468302 ,  0.7146298 ]],
#
#         [[ 0.24538915, -0.5502648 ,  0.6987318 ],
#          [ 0.2551519 , -0.5458364 ,  0.7068087 ],
#          [ 0.26167598, -0.5450257 ,  0.6967421 ],
#          ...,
#          [ 0.22863682, -0.45175406,  0.5797618 ],
#          [ 0.21037124, -0.45404512,  0.56981736],
#          [ 0.20459217, -0.4524326 ,  0.57240975]],
#
#         [[ 0.21390644, -0.47740635,  0.6020658 ],
#          [ 0.22822481, -0.46802086,  0.6137933 ],
#          [ 0.2401763 , -0.46625674,  0.6017732 ],
#          ...,
#          [ 0.25148785, -0.5278642 ,  0.72119534],
#          [ 0.25679487, -0.5285345 ,  0.7195618 ],
#          [ 0.25911433, -0.53401554,  0.7194656 ]]], dtype=float32)>)

# %%
model.load_weights(MODEL_PATH)

# %%
# ============================
# 5. Classifier Model Instantiation
# ============================

# Choose the model for classification. This is just for convenience, these models are actually wrappers around
#representation learning models.
# For example, using RepresentationLearningSingleAutoencoder
#model_classifier = ClassifierAutocovariance(model)

# Alternatively, you can choose other wrappers. 
# model_classifier = ClassifierAugmentedAutoencoder(model)
model_classifier = ClassifierMultipleAutoencoder(model)

"""Note: One should be careful about the compatibility of the classifier wrappers with the models. RepresentationLearningSingleAutoencoder and RepresentationLearningDenoising
Autoencoder are compatible with ClassifierAutocovariance, ClassifierAugmentedAutoencoder. However, RepresentationLearningMultipleAutoencoder is only compatible with 
ClassifierMultipleAutoencoder. """
# Out:
# 'Note: One should be careful about the compatibility of the classifier wrappers with the models. RepresentationLearningSingleAutoencoder and RepresentationLearningDenoising\nAutoencoder are compatible with ClassifierAutocovariance, ClassifierAugmentedAutoencoder. However, RepresentationLearningMultipleAutoencoder is only compatible with \nClassifierMultipleAutoencoder. '

# %%
# ============================
# 6. Obtain earthquake probabilities
# ============================
earthquake_scores = model_classifier(X_test)
# Out:
# 2025-06-29 13:46:07.434062: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1922039808 exceeds 10% of free system memory.
# 2025-06-29 13:46:07.926632: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1922039808 exceeds 10% of free system memory.
# 2025-06-29 13:46:08.345687: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1922039808 exceeds 10% of free system memory.
# 2025-06-29 13:46:27.137059: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1922039808 exceeds 10% of free system memory.
# 2025-06-29 13:46:45.589104: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1922039808 exceeds 10% of free system memory.

# %% [markdown]
# ## Save Plots with Model And Test Data Names

# %%
import os
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# Extract names for titles
test_data_name = os.path.basename(TEST_DATA_PATH).replace('.npy', '')
model_name = os.path.basename(MODEL_PATH).replace('.h5', '')

# Create plots directory
os.makedirs('./plots', exist_ok=True)

# Plot 1: Predictions vs True Labels
plt.figure(figsize=(10, 6))
plt.plot(earthquake_scores/np.max(earthquake_scores), '.-', label='Model Predictions (normalized)', alpha=0.7)
plt.plot(Y_test, '.-', label='True Labels', alpha=0.7)
plt.xlabel('Sample Index', fontsize=14)
plt.ylabel('Value', fontsize=14)
plt.title(f'Predictions vs True Labels\nTest Data: {test_data_name}\nModel: {model_name}', fontsize=12)
plt.legend(fontsize=12, loc='upper right')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig(f'./plots/{test_data_name}_{model_name}_predictions_vs_labels.png', dpi=300, bbox_inches='tight')
plt.show()

# Plot 2: ROC Curve
fpr, tpr, _ = roc_curve(Y_test, earthquake_scores)
auc_score = roc_auc_score(y_true=Y_test, y_score=earthquake_scores)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {auc_score:.3f})')
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--', label='Random Classifier')
plt.xlabel('False Positive Rate (FPR)', fontsize=14)
plt.ylabel('True Positive Rate (TPR)', fontsize=14)
plt.title(f'ROC Curve\nTest Data: {test_data_name}\nModel: {model_name}', fontsize=12)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig(f'./plots/{test_data_name}_{model_name}_roc_curve.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"Plots saved for {test_data_name} with {model_name}")
# Out:
# Plots saved for GAZK with MRMT_representation_multiple_5epochs
